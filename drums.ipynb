# %%
# %pip install spleeter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 46.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 MB 7.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 47.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 41.9 MB/s eta 0:00:00
# ...
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 23.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 39.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...

# %%
# !spleeter separate -p spleeter:4stems -o output data/top-50-raw/21-savage-redrum.mp3
# Out:
# INFO:spleeter:File output/21-savage-redrum/vocals.wav written succesfully
# INFO:spleeter:File output/21-savage-redrum/bass.wav written succesfully
# INFO:spleeter:File output/21-savage-redrum/drums.wav written succesfully
# INFO:spleeter:File output/21-savage-redrum/other.wav written succesfully

# %%
import os
import subprocess
import shlex
from pathlib import Path

# %%
# clean filenames
indir = Path("data/top-50-raw")
for filepath in indir.iterdir():
     if filepath.is_file():
         newname = filepath.name.replace(" ", "").replace(",", "").strip()
         newfilepath = filepath.with_name(newname)
         filepath.rename(newfilepath)

# %%
indir = Path("data/top-50-raw")
outdir = Path("data/top-50-drums")
for filepath in indir.iterdir():
     if filepath.is_file():
         filename = filepath.name
         isolate_cmd = f"spleeter separate -p spleeter:4stems -o output {filepath}"
         proc = subprocess.run(shl)
